# %% [markdown]
# # Analisa KURSET Virtual IDM Kendari

# %% [markdown]
# Untuk laporan kurang setor bisa dilihat di :
#
# https://docs.google.com/spreadsheets/d/1LVXuwtasHyM5r9wYa2GKy4k9cXT73f-c68fbykx2Abg/edit?usp=drive_link

# %% [markdown]
# ## Data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# conect to google drive
from google.colab import drive
drive.mount('content/')
# Out:
# Mounted at content/

# %%
#Data colection
data_path =('/content/content/MyDrive/Colab Notebooks/DATA/Kurset jan - nov.csv')
df = pd.read_csv(data_path, sep =",")
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1939 entries, 0 to 1938
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TOKO             1939 non-null   object
#  1   AS               1939 non-null   object
#  2   AM               1939 non-null   object
#  3   DESC             1939 non-null   object
#  4   NOMINAL          1939 non-null   object
#  5   PELAKU KURSET    1934 non-null   object
#  6   DAY              1939 non-null   int64
#  7   MONTH            1939 non-null   int64
#  8   YEAR             1939 non-null   int64
#  9   MMMM             1939 non-null   object
#  10  PENYEBAB KURSET  1939 non-null   object
#  11  CRITERIA         1939 non-null   object
#  12  PELUNASAN        1939 non-null   object
#  13  CEK KURSET       1939 non-null   object
# dtypes: int64(3), object(11)
# memory usage: 212.2+ KB
# (None,
# ...

# %%
df['PENYEBAB KURSET'].unique()
# Out:
# array(['SELISIH INPUT', 'TIDAK INPUT', 'FOOD', 'SELISIH FEE',
#        'SALAH INPUT', 'ISAKU', 'COD', 'OVO', 'VOUCHER', 'PAYMENT', 'BAF',
#        'BPJS', 'DOKU', 'FINNET', 'MST', 'PLN', 'SHOPEE', 'SALES DRAFT',
#        'DANA', 'GOPAY', 'APKA', 'IPULSA', 'QRBRI', 'SHOPEE PAY', '??'],
#       dtype=object)

# %%
Penyebap_kurset = df['PENYEBAB KURSET'].value_counts()
print(Penyebap_kurset)
Penyebap_kurset.plot(kind='bar')
# Out:
# PENYEBAB KURSET
# SELISIH INPUT    405
# TIDAK INPUT      374
# FOOD             374
# SELISIH FEE      313
# COD              282
# SALAH INPUT       77
# IPULSA            29
# SALES DRAFT       27
# ISAKU             15
# DANA               7
# SHOPEE             5
# DOKU               5
# VOUCHER            5
# APKA               4
# ??                 4
# PLN                2
# GOPAY              2
# OVO                2
# BPJS               1
# FINNET             1
# MST                1
# BAF                1
# PAYMENT            1
# QRBRI              1
# SHOPEE PAY         1
# Name: count, dtype: int64
# <Axes: xlabel='PENYEBAB KURSET'>

# %%
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Analisa Kurang setor

# %% [markdown]
# ### Gambaran masalah
#
# Kurang setor terjadi karena :
# - Human Eror
# - Eror System
#
# #### Jenis kurang setor Human Eror
#
# - Selisih input
# - Tidak input
# - Belum sattle
#
# #### System Eror
#
# - Komplainan Konsumen
# - RMB tidak naik
# - Restore data
# - Promo tidak main
#
# Pada data set diatas, terlihat top penyebab kurset adalah :
#
# |Jenis|Nominal|
# |-|-|
# |SELISIH INPUT|    405|
# |TIDAK INPUT|      374|
# |FOOD|             374|
# |SELISIH FEE|      313|
# |COD|              282|
# |SALAH INPUT|       77|
# |IPULSA|            29|
# |SALES DRAFT|       27|

# %% [markdown]
# ### Hasil temuan ditoko

# %% [markdown]
# Kurang setor selisih input karena :
# - Kasir baru lupa input tarik tunai
# - Tidak teliti kurang input angka 0
# - Input beda hari
#
# Penyebab Kurang setor :
# - EDC Offline
# - Tidak ada cross cek dari P. Shift
# - Kurang teliti

# %% [markdown]
# ## Solusi yang ditawarkan

# %% [markdown]
# - Laporan harian daftar EDC Offline (Follow up setingan)
# - Melakukan Reminder setiap hari di group
# - Melakukan meeting rutin bulanan untuk area yang paling sering kurset
# - Percepatan perbaikan EDC

# %% [markdown]
# ## Masukan untuk program

# %% [markdown]
# - Berikan jagaan pada pos yang ada tarik tunai, harus finger jika ada tarik tunai (Seperti cash out lainnya).
# - Minta tambahan warning message POS, (`"Periksa kembali sales draft apakah sudah sesuai?"`)
# - Percepatan EDC Online Yokke

# %% [markdown]
# ## Pembaharuan SOP

# %% [markdown]
# - Jika kasir baru kurset, P. shift harus ikut bertanggung jawab jika jagaan pada poin `masukan program` sudah jalan. Karena sudah ada cross check (Buatkan memo).
#
#  Tanggung jawab mereka terutama terletak pada pengawasan, verifikasi transaksi, dan penerapan SOP.
#
# Apabila pimpinan shift sudah melakukan semua prosedur dengan benar namun
